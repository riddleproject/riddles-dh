# %%
import numpy as np
import pandas as pd
import re
import os
from itertools import chain

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.svm import LinearSVC
from sklearn.metrics import f1_score, accuracy_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV, PredefinedSplit

from scipy.stats import uniform, randint

# %%
workPath = "workset/"

## skipPages is an optional parameter, which can be included
## if desired. It specifies pages that we should not even 
## consider when looking for riddles, in case someone spends
## time manually checking.
##
## skipPages should be filled with entries as follows:
## {"htID (should be the name of the folder)":pages to skip,
## "next htID":pages}
## Pages to skip will be represented as a list of ranges and
## integers.
## In order to represent a range of pages, you want to use 
## range(start, stop). Range is exclusive at the end, and
## indexing starts at 0, whereas page numbers start at 1, so 
## if you want to skip pages 1 through 10, you should put
## range(0, 11), if you want a single page, you can just write
## the number (page number - 1). It will simply ignore other 
## entries than integers and ranges

skipPages={"ht1":[range(0, 5), 7]}

for f in os.scandir(workPath):
    
    ## Within our workset, find folders (since volumes are imported as folders)
    if f.is_dir():
        
        ## Filter files in the folder for those ending in .txt and sort into
        ## alphabetical and numerical order, ascending. This allows us to stop
        ## looking once we get past the page which we think starts the end of
        ## the riddles, such as those containing "published" or related words
        skipList = range(0)
        for entry in skipPages.get(f.name, []):
            if type(entry) is range:
                skipList = chain(skipList, entry)
            elif type(entry) is int:
                skipList = chain(skipList, range(entry, entry+1))
        
        pageList = [p for p in sorted(os.scandir(workPath + f.name), key=lambda file: file.name) if p.name.endswith(".txt")]
        for i, page in enumerate(pageList):
            if i not in skipList:
                print(i)

[p for p in os.scandir(workPath + "ht1") if p.name.endswith(".txt")]

#print([f for f in os.scandir() if f.is_dir()])
# Out:
# 5
# 6
# 7
# [<DirEntry '8.txt'>,
#  <DirEntry '5.txt'>,
#  <DirEntry '4.txt'>,
#  <DirEntry '6.txt'>,
#  <DirEntry '7.txt'>,
#  <DirEntry '3.txt'>,
#  <DirEntry '2.txt'>,
#  <DirEntry '1.txt'>]

# %%
## Will take in the pathway of your workset folder and return 
## a pandas dataframe attempting to separate riddles into
## different rows. 
## 
## If you happen to know what page of the book
def createDataSet(path, skipPages=None):
    return None


## Function called in createDataSet, which takes in the text
## of one page and returns riddles found on the page as a list
## of strings, or None if none are found
def getRiddles(page, lookForIntro, lookForConclusion):
    return page
# Out:
# [<DirEntry '002_Summary of Proposal_18h24.docx'>, <DirEntry 'Worklog11-25.jpg'>, <DirEntry 'RA Task List.docx'>, <DirEntry 'To Do List.docx'>, <DirEntry '.DS_Store'>, <DirEntry 'UofT_Fisher MSS.04045 (Berwick).zip'>, <DirEntry 'Berney Manuscripts--MS.2016.009'>, <DirEntry 'Worklog.pptx'>, <DirEntry 'crumbtrail.docx'>, <DirEntry 'ASSIGNMENTS.docx'>, <DirEntry 'LibraryRANotebook.ipynb'>, <DirEntry 'Worklog11-18'>, <DirEntry 'Worklog12-09.jpg'>, <DirEntry 'Transcriptions'>, <DirEntry '~$umbtrail.docx'>, <DirEntry '009_Detailed Description_(NC; 18h54_5pages).docx'>, <DirEntry 'gems.docx'>, <DirEntry '.ipynb_checkpoints'>, <DirEntry 'Definitions.docx'>, <DirEntry 'Transcription Troubleshooting.docx'>, <DirEntry 'UCLA-Clark MS.1994'>, <DirEntry 'htrc_crumbtrail.docx'>, <DirEntry '~$rc_crumbtrail.docx'>, <DirEntry 'creating_collection_instructions.docx'>, <DirEntry 'The Brocklebank riddle.docx'>, <DirEntry '004_Roles and Training of Students (nc ls JAN19_Afternoon)_NS_224PM (NS and LS complete).docx'>, <DirEntry 'UofT_Fisher MSS.04045 (Berwick)'>, <DirEntry 'WorkLog Template (to be completed each Sunday by 18h please).xlsx'>]
# ['002_Summary of Proposal_18h24.docx',
#  'Worklog11-25.jpg',
#  'RA Task List.docx',
#  'To Do List.docx',
#  '.DS_Store',
#  'UofT_Fisher MSS.04045 (Berwick).zip',
#  'Berney Manuscripts--MS.2016.009',
#  'Worklog.pptx',
#  'crumbtrail.docx',
#  'ASSIGNMENTS.docx',
#  'LibraryRANotebook.ipynb',
#  'Worklog11-18',
#  'Worklog12-09.jpg',
#  'Transcriptions',
#  '~$umbtrail.docx',
#  '009_Detailed Description_(NC; 18h54_5pages).docx',
#  'gems.docx',
#  '.ipynb_checkpoints',
#  'Definitions.docx',
#  'Transcription Troubleshooting.docx',
#  'UCLA-Clark MS.1994',
#  'htrc_crumbtrail.docx',
#  '~$rc_crumbtrail.docx',
#  'creating_collection_instructions.docx',
#  'The Brocklebank riddle.docx',
#  '004_Roles and Training of Students (nc ls JAN19_Afternoon)_NS_224PM (NS and LS complete).docx',
#  'UofT_Fisher MSS.04045 (Berwick)',
#  'WorkLog Template (to be completed each Sunday by 18h please).xlsx']

# %%
cha = range(0)
for i in [range(10), 5, range(1,3)]:
    if type(i) is range:
        cha = chain(cha, i)
    elif type(i) is int:
        cha = chain(cha, range(i, i+1))
    
    
[i for i in cha]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-d91c611ca326> in <module>()
#       4
#       5
# ----> 6 [i for i in cha]
#
# <ipython-input-69-d91c611ca326> in <listcomp>(.0)
#       4
#       5
# ----> 6 [i for i in cha]
#
# TypeError: 'int' object is not iterable

# %%
[i for i in range(10, 11)]
# Out:
# [10]

# %%
def preProcess(dataset):
    temp = dataset.copy()
    temp[0] = temp[0].apply(lambda text: text.lower())
    temp[0] = temp[0].apply(lambda text: re.sub('<br />', ' ', text))
    temp[0] = temp[0].apply(lambda text: re.sub('[^a-z ]', '', text))
    return temp

def binBOW(dataset, counter):
    countArr = np.array(counter.transform(dataset[0]).toarray())
    countArr = (countArr != 0).astype(int)
    return pd.DataFrame(countArr, columns=counter.get_feature_names()).assign(lab=dataset[1])


def countBOW(dataset, counter):
    countArr = np.array(counter.transform(dataset[0]).toarray())
    return pd.DataFrame(countArr, columns=counter.get_feature_names()).assign(lab=dataset[1]).fillna(0)

# %%
imdbTrainSet = pd.read_csv(dataPath + '/IMDB-train.txt', sep='\t', lineterminator='\n', header=None)
imdbTrainSet = preProcess(imdbTrainSet)

imdbValidSet = pd.read_csv(dataPath + '/IMDB-valid.txt', sep='\t', lineterminator='\n', header=None)
imdbValidSet = preProcess(imdbValidSet)

imdbTestSet = pd.read_csv(dataPath + '/IMDB-test.txt', sep='\t', lineterminator='\n', header=None)
imdbTestSet = preProcess(imdbTestSet)

# %%
imdbTrainLabels = imdbTrainSet[1]
imdbValidLabels = imdbValidSet[1]
imdbTestLabels = imdbTestSet[1]
imdbTrainValidLabels = imdbTrainLabels.append(imdbValidLabels)

# %% [markdown]
# ## Counts Dataset

# %%
## Create vocabulary from training set
imdbCounter = CountVectorizer(max_features=10000)

imdbCounter.fit(imdbTrainSet[0])

imdbTrainCountsBOW = countBOW(imdbTrainSet, imdbCounter)

imdbValidCountsBOW = countBOW(imdbValidSet, imdbCounter)

imdbTestCountsBOW = countBOW(imdbTestSet, imdbCounter)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e7d0a10beee7> in <module>()
#       1 imdbCounter = CountVectorizer(max_features=10000)
#       2
# ----> 3 imdbCounter.fit(imdbTrainSet[0])
#       4
#       5 imdbTrainCountsBOW = countBOW(imdbTrainSet, imdbCounter)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in fit(self, raw_documents, y)
#     834         self
#     835         """
# --> 836         self.fit_transform(raw_documents)
#     837         return self
#     838
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     792             for feature in analyze(doc):
#     793                 try:
# --> 794                     feature_idx = vocabulary[feature]
#     795                     if feature_idx not in feature_counter:
#     796                         feature_counter[feature_idx] = 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## TFIDF

# %%
## Create object to transform data to tf-idf format
tf = TfidfVectorizer(max_features=20000, ngram_range=(1, 3))
tf.fit(imdbTrainSet[0])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=20000, min_df=1,
#         ngram_range=(1, 3), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
imdbTrainTfidf = pd.DataFrame(tf.transform(imdbTrainSet[0]).toarray(), columns=tf.get_feature_names())
imdbValidTfidf = pd.DataFrame(tf.transform(imdbValidSet[0]).toarray(), columns=tf.get_feature_names())
imdbTestTfidf = pd.DataFrame(tf.transform(imdbTestSet[0]).toarray(), columns=tf.get_feature_names())

# %% [markdown]
# ## LDA

# %%
lda = LatentDirichletAllocation(n_components=50, verbose=1)

# %%
lda.fit(imdbTrainCountsBOW)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-aaaa82d3e500> in <module>()
# ----> 1 lda.fit(imdbTrainCountsBOW)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/online_lda.py in fit(self, X, y)
#     550                     for idx_slice in gen_batches(n_samples, batch_size):
#     551                         self._em_step(X[idx_slice, :], total_samples=n_samples,
# --> 552                                       batch_update=False, parallel=parallel)
#     553                 else:
#     554                     # batch update
#
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/online_lda.py in _em_step(self, X, total_samples, batch_update, parallel)
#     431         # E-step
#     432         _, suff_stats = self._e_step(X, cal_sstats=True, random_init=True,
# --> 433                                      parallel=parallel)
#     434
#     435         # M-step
#
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/online_lda.py in _e_step(self, X, cal_sstats, random_init, parallel)
#     384                                               self.mean_change_tol, cal_sstats,
#     385                                               random_state)
# --> 386             for idx_slice in gen_even_slices(X.shape[0], n_jobs))
#     387
#     388         # merge result
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/online_lda.py in _update_doc_distribution(X, exp_topic_word_distr, doc_topic_prior, max_iters, mean_change_tol, cal_sstats, random_state)
#     114             # The optimal phi_{dwk} is proportional to
#     115             # exp(E[log(theta_{dk})]) * exp(E[log(beta_{dw})]).
# --> 116             norm_phi = np.dot(exp_doc_topic_d, exp_topic_word_d) + EPS
#     117
#     118             doc_topic_d = (exp_doc_topic_d *
#
# KeyboardInterrupt:

# %%
topicsLDA = pd.DataFrame(lda.components_, columns=imdbCounter.get_feature_names())

# %%
topicsLDAAbv = pd.DataFrame()
for index, row in topicsLDA.iterrows():
  topicsLDAAbv = topicsLDAAbv.append(pd.DataFrame([imdbCounter.get_feature_names()[i] for i in np.argsort(row)[:10]]).T)

# %%
imdbTrainLDA = pd.DataFrame(lda.transform(imdbTrainCountsBOW))
imdbValidLDA = pd.DataFrame(lda.transform(imdbValidCountsBOW))
imdbTestLDA = pd.DataFrame(lda.transform(imdbTestCountsBOW))

# %% [markdown]
# ## NMF

# %%
nmf = NMF(50, random_state=12345, verbose=True, max_iter=50)

# %%
nmf.fit(tf.transform(imdbTrainSet[0]))
# Out:
# violation: 1.0
# violation: 0.45193516442163384
# violation: 0.27040749107341405
# violation: 0.2269003629640173
# violation: 0.19471265878363694
# violation: 0.1680219115616303
# violation: 0.14634321747675158
# violation: 0.1280959351627554
# violation: 0.11126184270875411
# violation: 0.096245854798659
# violation: 0.08383522909534469
# violation: 0.07462237271109398
# violation: 0.0674753386113177
# violation: 0.06173654902399173
# violation: 0.05715771895666389
# violation: 0.05292050116651357
# violation: 0.04825694944913173
# violation: 0.043099224926664195
# violation: 0.03823581422461614
# violation: 0.03361318309606829
# violation: 0.02956926461211621
# violation: 0.026060124131232973
# violation: 0.023101227964494184
# violation: 0.02066925785243767
# violation: 0.018725941758225124
# violation: 0.01720791367852676
# violation: 0.016005916251278226
# violation: 0.015096982944780643
# violation: 0.014408330633712637
# violation: 0.01389265127773106
# violation: 0.013490081225559019
# violation: 0.01314065002743634
# violation: 0.012846563314509065
# violation: 0.012525288804341143
# violation: 0.01219138228485472
# violation: 0.0118084463099089
# violation: 0.011364889217722551
# violation: 0.010885086491978632
# violation: 0.010367205238137143
# violation: 0.009831632701369882
# violation: 0.009301425290167179
# violation: 0.008793775196490227
# violation: 0.008334215532449197
# violation: 0.007931334751358723
# violation: 0.007579282636755474
# violation: 0.007268770428258815
# violation: 0.00699804190423582
# violation: 0.006756190914643413
# violation: 0.00651354572392913
# violation: 0.006270973396020573
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=50,
#   n_components=50, random_state=12345, shuffle=False, solver='cd',
#   tol=0.0001, verbose=True)

# %%
topicsNMF = pd.DataFrame(nmf.components_, columns=tf.get_feature_names())
topicsNMF
# Out:
#     abandoned       abc  abilities   ability  ability to      able   able to  \
# 0    0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 1    0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 2    0.027532  0.000000   0.000000  0.004748    0.017896  0.012393  0.013245
# 3    0.000000  0.000000   0.000000  0.000000    0.000000  0.018114  0.018354
# 4    0.000000  0.000000   0.004758  0.000000    0.000000  0.000000  0.000000
# 5    0.000465  0.000000   0.004767  0.009759    0.000000  0.012470  0.012649
# 6    0.000000  0.000000   0.000000  0.022523    0.009678  0.014298  0.011378
# 7    0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 8    0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 9    0.000000  0.000000   0.000000  0.000000    0.000000  0.001688  0.000000
# 10   0.000000  0.000000   0.000000  0.000000    0.000000  0.024630  0.025001
# 11   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 12   0.000000  0.151263   0.000666  0.000000    0.000000  0.002404  0.001664
# 13   0.005452  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 14   0.000000  0.000000   0.000000  0.012255    0.004818  0.000000  0.000000
# 15   0.000000  0.000000   0.000000  0.000000    0.000000  0.003954  0.004923
# 16   0.000000  0.000000   0.016657  0.023240    0.017596  0.271510  0.267763
# 17   0.000000  0.000000   0.000000  0.007400    0.000000  0.000000  0.000000
# 18   0.000000  0.000000   0.017870  0.000000    0.001434  0.000000  0.000000
# 19   0.000000  0.000000   0.000000  0.011472    0.010162  0.000000  0.000000
# 20   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 21   0.000000  0.003401   0.000000  0.000000    0.000000  0.014390  0.016129
# 22   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 23   0.000000  0.000000   0.000000  0.000000    0.002411  0.001523  0.000000
# 24   0.000000  0.009074   0.000000  0.000000    0.000000  0.025360  0.029711
# 25   0.000000  0.000000   0.000000  0.018155    0.000000  0.008811  0.008482
# 26   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 27   0.003820  0.000000   0.000000  0.026887    0.008402  0.000000  0.000000
# 28   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 29   0.000000  0.000000   0.000000  0.000000    0.000000  0.008538  0.006233
# 30   0.000000  0.000000   0.000000  0.000000    0.000000  0.002353  0.000000
# 31   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 32   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 33   0.006253  0.000000   0.006819  0.000000    0.000000  0.000000  0.000000
# 34   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 35   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 36   0.000000  0.000000   0.005760  0.000000    0.002550  0.000000  0.000000
# 37   0.000000  0.000000   0.000328  0.000000    0.000000  0.000000  0.000000
# 38   0.000000  0.000000   0.000000  0.003909    0.000228  0.000000  0.000000
# 39   0.000000  0.010657   0.003263  0.000000    0.000000  0.011138  0.012894
# 40   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 41   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 42   0.000000  0.000000   0.001437  0.000000    0.000000  0.000000  0.000000
# 43   0.000000  0.000000   0.000000  0.000375    0.000000  0.000000  0.000000
# 44   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 45   0.011718  0.000000   0.000000  0.012174    0.004214  0.000000  0.000000
# 46   0.000000  0.000000   0.010664  0.004135    0.000000  0.000000  0.000000
# 47   0.015719  0.000000   0.000000  0.001440    0.011380  0.008565  0.003517
# 48   0.000000  0.000000   0.000000  0.000000    0.000000  0.000000  0.000000
# 49   0.010579  0.000000   0.000000  0.022739    0.018599  0.000000  0.000000
#
#        about  about all  about an    ...     yourself  yourself favor  \
# 0   0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 1   0.045005   0.000000  0.001530    ...     0.019344        0.004828
# 2   0.022217   0.000000  0.003781    ...     0.004760        0.000000
# 3   0.084896   0.000000  0.002021    ...     0.000000        0.000000
# 4   0.022148   0.000000  0.005398    ...     0.000000        0.000000
# 5   0.003373   0.000000  0.000000    ...     0.000000        0.000000
# 6   0.090096   0.000000  0.005454    ...     0.000000        0.000000
# 7   0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 8   0.061119   0.000000  0.005050    ...     0.000000        0.000000
# 9   0.000000   0.000000  0.002619    ...     0.000000        0.000000
# 10  0.056891   0.000000  0.000000    ...     0.192172        0.012323
# 11  0.203838   0.000000  0.014351    ...     0.000000        0.000000
# 12  0.005842   0.000000  0.000000    ...     0.005874        0.000868
# 13  0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 14  0.261393   0.001132  0.000000    ...     0.000000        0.000000
# 15  0.000000   0.000000  0.007643    ...     0.000000        0.000000
# 16  0.000000   0.000000  0.004806    ...     0.017957        0.000000
# 17  0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 18  0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 19  0.237837   0.000000  0.000000    ...     0.000000        0.000000
# 20  0.062338   0.000000  0.000000    ...     0.007779        0.006960
# 21  0.000000   0.000000  0.000000    ...     0.000000        0.011050
# 22  0.193199   0.000000  0.000000    ...     0.008122        0.000000
# 23  0.083487   0.005742  0.014713    ...     0.000000        0.000000
# 24  0.058556   0.000000  0.000000    ...     0.000000        0.000000
# 25  0.000000   0.000635  0.001910    ...     0.000000        0.005024
# 26  0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 27  0.000000   0.000000  0.004005    ...     0.011989        0.000000
# 28  0.011814   0.000000  0.000233    ...     0.029585        0.008264
# 29  0.244282   0.000000  0.000000    ...     0.000000        0.000000
# 30  0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 31  0.000000   0.000000  0.015874    ...     0.000000        0.000000
# 32  0.000000   0.000000  0.000000    ...     0.001147        0.000000
# 33  0.013055   0.000000  0.000000    ...     0.000000        0.000000
# 34  0.055631   0.000000  0.004945    ...     0.054302        0.026958
# 35  0.070175   0.000000  0.000000    ...     0.001959        0.000000
# 36  0.089777   0.003264  0.000077    ...     0.000000        0.000000
# 37  0.000000   0.000000  0.000000    ...     0.000000        0.004527
# 38  0.000000   0.000000  0.001284    ...     0.000000        0.000000
# 39  0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 40  0.242373   0.008545  0.003766    ...     0.000000        0.000000
# 41  0.062101   0.058545  0.000000    ...     0.003187        0.000000
# 42  0.000000   0.000000  0.000000    ...     0.028445        0.012666
# 43  0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 44  0.000000   0.000907  0.000000    ...     0.028940        0.000000
# 45  0.000000   0.000000  0.010716    ...     0.000000        0.000000
# 46  0.000000   0.000000  0.000000    ...     0.000000        0.000000
# 47  0.487511   0.008029  0.010003    ...     0.000000        0.000000
# 48  0.000000   0.000000  0.002061    ...     0.000000        0.000000
# 49  0.044860   0.000000  0.000939    ...     0.000000        0.000000
#
#        youth     youve  youve got  youve seen      zero    zombie   zombies  \
# 0   0.009385  0.000000   0.000000    0.000000  0.000000  0.000000  0.014253
# 1   0.000000  0.000000   0.000000    0.000000  0.006620  0.000000  0.000000
# 2   0.000000  0.014837   0.004764    0.003513  0.000000  0.105521  0.070755
# 3   0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000   0.000000    0.000000  0.012941  0.000000  0.000000
# 5   0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 6   0.019775  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 7   0.025254  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000   0.002463    0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.074521   0.004295    0.026612  0.002775  0.000000  0.000000
# 11  0.000000  0.077925   0.016662    0.009562  0.000000  0.020440  0.032062
# 12  0.000000  0.000000   0.001436    0.000000  0.000000  0.000000  0.000000
# 13  0.020046  0.000000   0.000000    0.004056  0.000000  0.000000  0.000000
# 14  0.000000  0.000000   0.000000    0.000000  0.033095  0.000000  0.000000
# 15  0.000000  0.000000   0.000000    0.000000  0.004774  0.000000  0.000000
# 16  0.000000  0.000000   0.000000    0.000000  0.013449  0.000000  0.000000
# 17  0.002892  0.005890   0.007172    0.000000  0.000000  0.010944  0.003132
# 18  0.000000  0.000000   0.000000    0.000164  0.000000  0.000000  0.000000
# 19  0.000000  0.000000   0.000000    0.000000  0.009448  0.000000  0.000000
# 20  0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.024500   0.000000    0.008065  0.014935  0.000000  0.000000
# 22  0.000000  0.000000   0.000000    0.000183  0.009790  0.000000  0.000000
# 23  0.002787  0.000000   0.000000    0.007762  0.000000  0.000000  0.000000
# 24  0.000551  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 25  0.000000  0.011002   0.000000    0.011594  0.000000  0.002971  0.000000
# 26  0.000000  0.000000   0.000000    0.000000  0.001328  0.000000  0.000000
# 27  0.000000  0.000000   0.016764    0.000000  0.024157  0.137481  0.119705
# 28  0.000000  0.059750   0.005796    0.028677  0.025412  0.081568  0.041822
# 29  0.005190  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 30  0.000000  0.004477   0.001616    0.000000  0.000000  0.000000  0.000000
# 31  0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 32  0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 33  0.000000  0.006366   0.000000    0.000000  0.022253  0.017061  0.002430
# 34  0.000000  0.027463   0.010311    0.000431  0.027475  0.000000  0.000000
# 35  0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 36  0.000000  0.000000   0.000000    0.000000  0.002215  0.000000  0.000000
# 37  0.000000  0.000000   0.000057    0.000000  0.000000  0.000000  0.000000
# 38  0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 39  0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 40  0.000000  0.000000   0.005008    0.000000  0.000000  0.000000  0.013509
# 41  0.002461  0.027142   0.000000    0.010510  0.000000  0.000000  0.000000
# 42  0.000000  0.000000   0.000000    0.000000  0.003306  0.000000  0.000000
# 43  0.000000  0.000000   0.000000    0.000000  0.000000  0.000000  0.000000
# 44  0.001474  0.000000   0.000000    0.002493  0.012875  0.000000  0.000000
# 45  0.005819  0.001788   0.009534    0.000000  0.000000  0.000000  0.000000
# 46  0.000000  0.000000   0.000000    0.001925  0.000000  0.001548  0.000000
# 47  0.011516  0.000000   0.004001    0.000000  0.000000  0.000000  0.000000
# 48  0.000304  0.000000   0.000715    0.000000  0.000000  0.000000  0.000000
# 49  0.000000  0.000000   0.000918    0.000000  0.000000  0.000000  0.000000
#
#         zone
# 0   0.000000
# 1   0.000000
# 2   0.003704
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.001599
# 12  0.000000
# 13  0.002234
# 14  0.000000
# 15  0.000000
# 16  0.002809
# 17  0.001659
# 18  0.006743
# 19  0.000000
# 20  0.003762
# 21  0.000000
# 22  0.000000
# 23  0.007856
# 24  0.012108
# 25  0.000000
# 26  0.000000
# 27  0.000000
# 28  0.003412
# 29  0.000000
# 30  0.000000
# 31  0.000000
# 32  0.000000
# 33  0.000622
# 34  0.000000
# 35  0.000000
# 36  0.000000
# 37  0.000000
# 38  0.000000
# 39  0.068494
# 40  0.003937
# 41  0.000000
# 42  0.000000
# 43  0.000000
# 44  0.000000
# 45  0.000000
# 46  0.000000
# 47  0.004071
# 48  0.000000
# 49  0.000000
#
# [50 rows x 15000 columns]

# %%
topicsNMFAbv = pd.DataFrame()
for index, row in topicsNMF.iterrows():
  topicsNMFAbv = topicsNMFAbv.append(pd.DataFrame([tf.get_feature_names()[i] for i in np.argsort(row)[:10]]).T)
topicsNMFAbv
# Out:
#            0                1                     2                  3  \
# 0  abandoned         over her              over his            over it
# 0  abandoned             quit                 quite           quite as
# 0  mean that   there were few                 lynch             lyrics
# 0  abandoned       population                  porn              porno
# 0  abandoned           poetry              poignant              point
# 0  mean that         par with                parade           parallel
# 0  abandoned      perhaps the                period          period of
# 0  abandoned    realized that              realizes      realizes that
# 0  abandoned         read the         read the book            reading
# 0  abandoned       quite good             quite the             rabbit
# 0  abandoned         problems          problems and      problems with
# 0  abandoned           priest             primarily            primary
# 0  abandoned  performances by     performances from    performances in
# 0  mean that    not enough to              not even        not exactly
# 0  abandoned      playing the                 plays          plays the
# 0  abandoned        pointless                points          points of
# 0  abandoned     photographer       photography and             photos
# 0  abandoned         ready to                  real           real and
# 0  abandoned          portion            portion of   portrayal of the
# 0  abandoned          produce              produced        produced by
# 0  abandoned           people            people and         people are
# 0  abandoned         pathetic               patient           patients
# 0  abandoned            raise                raised             raises
# 0  abandoned        points of                poison           polanski
# 0  abandoned            posey              position          possessed
# 0  abandoned            phase            phenomenon             philip
# 0  abandoned    really wanted      really wanted to         really was
# 0  mean that           planet               planned           planning
# 0  abandoned        not movie              not much             not my
# 0  abandoned              pat              pathetic            patient
# 0  abandoned  probably one of          probably the  probably the most
# 0  abandoned          pulling                  pulp                pun
# 0  abandoned         practice                praise           precious
# 0    is pure        next time               next to         to support
# 0  abandoned       pleasantly  pleasantly surprised            pleased
# 0  abandoned        primarily               primary              prime
# 0  abandoned     photographed          photographer        photography
# 0  abandoned         power to              powerful       powerful and
# 0  abandoned     reading this                 reads           ready to
# 0  abandoned       not in the                not it           not know
# 0  abandoned          mustsee                mutual                 my
# 0  abandoned              raw                   ray            raymond
# 0  abandoned        principal                 print             prison
# 0  abandoned          put the              put this             put to
# 0  abandoned     probably the     probably the best  probably the most
# 0  mean that         progress            progresses           projects
# 0  abandoned         poor and        poorly written               pops
# 0  mean that            noone                  nope            totally
# 0  abandoned   performance in        performance is   performance that
# 0  mean that         pictures                   pie           piece of
#
#                  4                5                     6               7  \
# 0   over the place       over years            overacting         overall
# 0        quite bit       quite good             quite the      quite well
# 0        macarthur       there were              machines            macy
# 0       portion of         portrait           portrait of       portrayal
# 0        point and         point in          point in the        point of
# 0        paramount         paranoia                 paris          parody
# 0    personalities       personally               persons     perspective
# 0        realizing           really            really bad       really be
# 0      reading the     reading this                 reads           ready
# 0             race           racial                racism          racist
# 0      proceedings         proceeds           proceeds to         process
# 0            prime           prince              princess       principal
# 0  performances of        performed             performer      performers
# 0         not find          not for           not for the       not funny
# 0         pleasant       pleasantly  pleasantly surprised          please
# 0           poison         polanski                  pole          police
# 0          physics            piano                  pick         pick up
# 0        real life      real people            real world         realise
# 0     portrayed in            posey              position        positive
# 0         producer        producers            production  production and
# 0       people but      people dont           people have       people in
# 0          patrick            paula                paulie             pay
# 0          raising              raj                 ralph           rambo
# 0             pole           police            police and  police officer
# 0      possibility         possible           possible to        possibly
# 0    philosophical       philosophy                 phone           phony
# 0           reason       reason for            reason the       reason to
# 0            plans            plant             plausible            play
# 0       not nearly  not necessarily                not on      not one of
# 0         patients          patrick                  paul           paula
# 0          problem       problem is       problem is that    problem with
# 0            punch       punishment                  punk          puppet
# 0        precisely  predictable and                prefer        pregnant
# 0          to such          nice to           nice to see          nicely
# 0         pleasure      pleasure to                plenty       plenty of
# 0        primitive           prince              princess           print
# 0  photography and           photos                phrase        physical
# 0      practically         practice                praise        precious
# 0             real         real and             real life     real people
# 0      not knowing         not make             not movie        not much
# 0    to be desired     my attention               my eyes       my father
# 0               rd          reached               reaches           react
# 0         prisoner        prisoners                 prize        probably
# 0     put together           put up                  puts      quality is
# 0          problem       problem is       problem is that    problem with
# 0         promised         promises             promising           proof
# 0          popular       population                 porno         portion
# 0         normally            total                 north            nose
# 0  performance was        performer            performers      performing
# 0    piece of crap        pieces of                   pig            pile
#
#                   8                 9
# 0        overall it       overall the
# 0             quote            rabbit
# 0              lust       there wasnt
# 0      portrayal of  portrayal of the
# 0      point of the     point of view
# 0         parody of          part and
# 0                pg     philosophical
# 0       really cant       really care
# 0         ready for          ready to
# 0             radio              rage
# 0           produce          produced
# 0             prior          prior to
# 0        performing          performs
# 0           not get            not go
# 0         please do           pleased
# 0        police and    police officer
# 0            picked         picked up
# 0          realised           realism
# 0         possessed     possibilities
# 0     production is     production of
# 0     people in the       people like
# 0     pay attention           pay for
# 0               ran            random
# 0         policeman          polished
# 0      possibly the            posted
# 0             photo      photographed
# 0        reasonable        reasonably
# 0          play and          play the
# 0           try and       not only is
# 0            paulie              pays
# 0  problem with the          problems
# 0          purchase         purchased
# 0        premise of           prepare
# 0          nicholas           to stop
# 0            plight           plot in
# 0             prior          prior to
# 0        physically           physics
# 0         precisely   predictable and
# 0        real world           realise
# 0            not my            not in
# 0       my favorite      my favorites
# 0          reaction         reactions
# 0       probably be  probably because
# 0        quality of    quality of the
# 0  problem with the          problems
# 0        propaganda            proper
# 0           portray         portrayal
# 0         nostalgia         nostalgic
# 0        perhaps it         period of
# 0           pile of             pilot

# %%
imdbTrainNMF = pd.DataFrame(nmf.transform(imdbTrainTfidf))
imdbValidNMF = pd.DataFrame(nmf.transform(imdbValidTfidf))
imdbTestNMF = pd.DataFrame(nmf.transform(imdbTestTfidf))
# Out:
# violation: 1.0
# violation: 0.3791686611747777
# violation: 0.07770474082115794
# violation: 0.01753921221900882
# violation: 0.006268721300653509
# violation: 0.002023346850763037
# violation: 0.0005111057638289919
# violation: 0.00013609782327786963
# violation: 4.8025682886756333e-05
# Converged at iteration 9
# violation: 1.0
# violation: 0.3789681024894265
# violation: 0.07895929869017258
# violation: 0.017925624966645272
# violation: 0.00649362375433549
# violation: 0.002131292013459603
# violation: 0.0005425433717860234
# violation: 0.00014479611562148685
# violation: 5.1442179713407275e-05
# Converged at iteration 9
# violation: 1.0
# violation: 0.37805065366124024
# violation: 0.07826313298815687
# violation: 0.01775626504030134
# violation: 0.006399301913928864
# violation: 0.002089502627417968
# violation: 0.0005300670430229202
# violation: 0.0001412985402496063
# violation: 5.018799293410001e-05
# Converged at iteration 9

# %% [markdown]
# ## TFIDF Alone Tuning

# %%
bestSVM = None
bestScore = 0
for n_components in np.linspace(100, 10000, 10, dtype=int):
    for nMax in range(1, 4):
        for nMin in [1, nMax]:
            ## Create object to transform data to tf-idf format
            tf = TfidfVectorizer(max_features=n_components, ngram_range=(nMin, nMax))
            tf.fit(imdbTrainSet[0])
  
            imdbTrainTfidf = pd.DataFrame(tf.transform(imdbTrainSet[0]).toarray(), columns=tf.get_feature_names())
            imdbValidTfidf = pd.DataFrame(tf.transform(imdbValidSet[0]).toarray(), columns=tf.get_feature_names())
      
            imdbTrainValidTfidf = imdbTrainTfidf.append(imdbValidTfidf)
  
            svm = LinearSVC()
      svmParams = [{'kernel': ['rbf'],
                    'C': [2**x for x in range(-5, 6)],
                    'gamma': np.linspace(0.0001, 0.999, 8)},
                   {'kernel': ['linear'],
                    'C': [2**x for x in range(-5, 6)]},
                   {'kernel': ['poly'],
                    'C': [2**x for x in range(-5, 6)],
                    'gamma': np.linspace(0.0001, 0.999, 8),
                    'coef0': [0, 1]}]
      ps = PredefinedSplit(test_fold=np.concatenate((-1*np.ones(imdbTrainTfidf.shape[0]), np.zeros(imdbValidTfidf.shape[0]))))
      gSearchSVM = GridSearchCV(svm, svmParams, verbose=3, scoring='accuracy', cv=ps, error_score=0)
      gSearchSVM.fit(imdbTrainValidTfidf, imdbTrainValidLabels)

      print(gSearchSVM.best_score_)
      if gSearchSVM.best_score_ > bestScore:
        bestScore = SearchSVM.best_score_
        bestSVM = gSearch.best_estimator_
        print('Best score yet!')
        print('n_components:')
        print(n_components)
        
        print('nMax:')
        print(nMax)
        
        print('nMin:')
        print(nMin)

# %%
gSearchSVM.best_estimator_
# Out:
# SVC(C=2, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.999, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svm = LinearSVC(verbose=True)

svmParams = {'C': [2**x for x in range(-5, 6)]},
ps = PredefinedSplit(test_fold=np.concatenate((-1*np.ones(imdbTrainTfidf.shape[0]), np.zeros(imdbValidTfidf.shape[0]))))

imdbTrainValidTfidf = imdbTrainTfidf.append(imdbValidTfidf)

gSearchSVM = GridSearchCV(svm, svmParams, verbose=3, scoring='accuracy', cv=ps, error_score=0)
gSearchSVM.fit(imdbTrainValidTfidf, imdbTrainValidLabels)


svm.fit(imdbTrainTfidf, imdbTrainLabels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3b88fb460765> in <module>()
# ----> 1 svm = LinearSVC(verbose=True)
#       2
#       3 svmParams = {'C': [2**x for x in range(-5, 6)]},
#       4 ps = PredefinedSplit(test_fold=np.concatenate((-1*np.ones(imdbTrainTfidf.shape[0]), np.zeros(imdbValidTfidf.shape[0]))))
#       5
#
# NameError: name 'LinearSVC' is not defined

# %%
svm = LinearSVC(verbose=True, C=0.4)
svm.fit(imdbTrainTfidf, imdbTrainLabels)
validPreds = svm.predict(imdbValidTfidf)
accuracy_score(imdbValidLabels, validPreds)
# Out:
# [LibLinear]
# 0.8909

# %%
svm = LinearSVC(verbose=True, C=0.15)
svm.fit(pd.concat((imdbTrainNMF, imdbTrainTfidf), axis=1), imdbTrainLabels)
validPreds = svm.predict(pd.concat((imdbValidNMF, imdbValidTfidf), axis=1))
accuracy_score(imdbValidLabels, validPreds)
# Out:
# [LibLinear]
# 0.8852
